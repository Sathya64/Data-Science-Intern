# %%
import pandas as pd
heart_disease_data = pd.read_csv("C:\\Users\\welcome\\Downloads\\Desktop\\archive.zip")
print("First few rows of the dataset:")
print(heart_disease_data.head())
print("\nChecking for missing values:")
print(heart_disease_data.isnull().sum())
print("\nSummary statistics of the dataset:")
print(heart_disease_data.describe())
# Out:
# First few rows of the dataset:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
#
# Checking for missing values:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64
#
# Summary statistics of the dataset:
# ...

# %%
import pandas as pd
d=pd.read_csv("C:\\Users\\welcome\\Downloads\\Desktop\\archive.zip")
df=pd.DataFrame(d)
type(df)
len(df)
df.shape

# Display the first 5 rows of the DataFrame
print(df.head())
#Display the last five rows of the DataFrame
print(df.tail())


#display all columns and their data types
df.info()


#display some basic descriptive statistics for all numeric columns
df.describe()

# Check for missing values in each column
missing_values_per_column = df.isnull().sum()

# Display the count of missing values in each column
print("Missing values in each column:")
print(missing_values_per_column)
# Check for missing values in each row
missing_values_per_row = df.isnull().sum(axis=1)

# Display the count of missing values in each row
print("Missing values in each row:")
print(missing_values_per_row)

# Display summary statistics
print(df.describe())

#average
d["sex"].mean()

#median
d[["age","sex"]].median()

#using the DataFrame.agg() method:
d.agg(
    {
        "age": ["min", "max", "median", "skew"],
        "sex": ["min", "max", "median", "mean"],
    }
)


d[["sex", "age"]].groupby("sex").mean()
 

d.groupby("sex").mean(numeric_only=True)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# ...
